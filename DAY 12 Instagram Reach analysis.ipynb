# %% [markdown]
# 1) importing the data
# 2) reading the data
# 3) data understanding
# 4) data cleaning
# 5) data viz as per questions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data
df = pd.read_csv(r"/Users/sushanth/Downloads/Instagram_data.csv", engine='python',encoding='ISO-8859-1')
df
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
#Data understanding
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
#tail
df.tail()
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 114         2      38    373              73       80
# 115         4       1    148              20       18
# 116         0       1     92              34       10
# 117         2      75    549             148      214
# 118         5      26    443             611      228
#
#                                                Caption  \
# 114  Here are some of the best data science certifi...
# 115  Clustering is a machine learning technique use...
# ...

# %%
#shape
df.shape
# Out:
# (119, 13)

# %%
#columns
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags'],
#       dtype='object')

# %%
#to get information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %% [markdown]
# * Total 119 records are present in data set
# * Out of 13 columns ,11 columns are integer and 2 columns are textual

# %%
#to get the statistical information
df.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %%
df.describe().transpose()
# Out:
#                 count         mean          std     min     25%     50%  \
# Impressions     119.0  5703.991597  4843.780105  1941.0  3467.0  4289.0
# From Home       119.0  2475.789916  1489.386348  1133.0  1945.0  2207.0
# From Hashtags   119.0  1887.512605  1884.361443   116.0   726.0  1278.0
# From Explore    119.0  1078.100840  2613.026132     0.0   157.5   326.0
# From Other      119.0   171.092437   289.431031     9.0    38.0    74.0
# Saves           119.0   153.310924   156.317731    22.0    65.0   109.0
# Comments        119.0     6.663866     3.544576     0.0     4.0     6.0
# Shares          119.0     9.361345    10.089205     0.0     3.0     6.0
# Likes           119.0   173.781513    82.378947    72.0   121.5   151.0
# Profile Visits  119.0    50.621849    87.088402     4.0    15.0    23.0
# Follows         119.0    20.756303    40.921580     0.0     4.0     8.0
#
#                    75%      max
# Impressions     6138.0  36919.0
# From Home       2602.5  13473.0
# ...

# %%
#Check the null values
df.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
#check duplicate values
df.duplicated().sum()
# Out:
# 17

# %%
#Handle the duplicate values
df.drop_duplicates(inplace=True,ignore_index=True)
df
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 97         13700       5185           3041          5352          77    573
# 98          5731       1923           1368          2266          65    135
# 99          4139       1133           1538          1367          33     36
# 100        32695      11815           3147         17414         170   1095
# 101        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (102, 13)

# %%
#check unique values

df.nunique()
# Out:
# Impressions       101
# From Home          97
# From Hashtags     100
# From Explore       95
# From Other         84
# Saves              84
# Comments           15
# Shares             28
# Likes              85
# Profile Visits     59
# Follows            29
# Caption            90
# Hashtags           54
# dtype: int64

# %%
#checking the outlayers using unique and value count method
df["Impressions"].unique()
# Out:
# array([ 3920,  5394,  4021,  4528,  2518,  3884,  2621,  3541,  3749,
#         4115,  2218,  3234,  4344,  3216,  9453,  5055,  4002,  3169,
#         6168,  2407,  2064,  3973,  7281,  3052,  4628,  4082,  2766,
#         3924,  3015,  6666,  3854,  4355,  4343,  6108,  2523,  2327,
#         3990,  2191,  1941, 16062,  4998,  4289,  3880,  3786,  4298,
#         3630,  2826,  7407, 10386,  2998,  7018,  2941,  6432, 10667,
#         3988,  4978,  3388,  4467,  3246,  5072,  6339,  4239,  3454,
#         7571,  3333,  3818, 10933,  5058,  3601,  3480,  3525,  3606,
#         5542,  6559,  3623, 10493,  4446,  2957,  5538,  4681,  5273,
#         5409,  5323,  8001,  4150,  4609,  6348, 11068,  7231, 17396,
#         6814, 17713,  5563,  4842, 11149, 10206, 13700,  5731,  4139,
#        32695, 36919])

# %%
df["Impressions"].value_counts()
# Out:
# 5394     2
# 7571     1
# 6559     1
# 5542     1
# 3606     1
#         ..
# 3854     1
# 6666     1
# 3015     1
# 3924     1
# 36919    1
# Name: Impressions, Length: 101, dtype: int64

# %%
#To analyse the distribution of each column
plt.figure(figsize=(10,5))
sns.distplot(df['Impressions'])
plt.title("Distribution of Impressions")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/3290839816.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Impressions'])

# %%
df["From Home"].unique()
# Out:
# array([ 2586,  2727,  2085,  2700,  1704,  2046,  1543,  2071,  2384,
#         2609,  1597,  2414,  2168,  2524,  2525,  2017,  3401,  1979,
#         2177,  1338,  1304,  2415,  3065,  2608,  2406,  2195,  2275,
#         2541,  2244,  2034,  1977,  1975,  2879,  2278,  2679,  1659,
#         1774,  2123,  1308,  1466,  3144,  2331,  2746,  2207,  2632,
#         3050,  1747,  2108,  2782,  4137,  1945,  2569,  1716,  2812,
#         3152,  2125,  1910,  2508,  1780,  2190,  1711,  1663,  3717,
#         1502,  2357,  1570,  1323,  2509,  1782,  2225,  1179,  2106,
#         2454,  1926,  2597,  2252,  2673,  2643,  2000,  2261,  1807,
#         2032,  2517,  2099,  1855,  1817,  2816,  2449,  3813,  1658,
#         4439,  2371,  5185,  1923,  1133, 11815, 13473])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['From Home'])
plt.title("Distribution of From Home")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/2152785699.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Home'])

# %%
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags'],
#       dtype='object')

# %%
df["From Hashtags"].unique()
# Out:
# array([ 1028,  1838,  1188,   621,   255,  1214,   599,   628,   857,
#         1104,   411,   476,  1274,   212,  5799,  2351,   278,   707,
#         3450,   655,   362,   745,  1254,   201,  1260,  1248,  2975,
#          116,  1278,   771,  4604,  1721,   139,  1460,  2803,   796,
#          435,  1482,   809, 11817,  2195,   869,  1109,   616,   969,
#         1693,   583,  1938,  3551,   794,  4221,  1058,  2974,  6564,
#          802,  2249,  1018,  1880,   166,  3090,  4036,  2429,  1284,
#          841,  1423,   442,  6610,  2250,  1518,  1019,  1699,   183,
#         3212,  4041,  1527,  7761,  1590,   349,  2376,  1674,  2003,
#         2006,  2053,  5055,  1085,   911,  2660,  2986,  4156, 10008,
#         2769,  2141,   694,   747,  1624,  3041,  1368,  1538,  3147,
#         4176])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['From Hashtags'])
plt.title("Distribution of Hashtags")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/3807173548.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Hashtags'])

# %%
df["From Explore"].unique()
# Out:
# array([  619,  1174,     0,   932,   279,   329,   333,   500,   248,
#          178,   162,   185,   673,   201,   208,   298,   128,   341,
#          153,   276,   249,   676,  2081,   121,   861,   541,    45,
#           51,   326,   115,    48,    60,  1239,   521,   562,    29,
#           59,   332,    37,   564,   318,   589,   199,   468,   181,
#           72,    76,  2237,  2355,    84,   796,   617,   545,   354,
#          244,   492,   360,    69,    36,   166,  1716,   182,   250,
#          623,   362,   174,   245,   446,   213,   158,   157,   192,
#          217,   412,   433,  1068,   988,   300,   463,   857,   737,
#         5634,   703,  5192,   900, 12389,  1135,  2036,  5762,  6000,
#         5352,  2266,  1367, 17414, 16444])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['From Explore'])
plt.title("Distribution of Explore")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/3329017180.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Explore'])

# %%
df["From Other"].unique()
# Out:
# array([  56,   78,  533,   73,   37,   43,   25,   60,   49,   46,   15,
#          75,   40,  223,  794,  108,   32,  296,   39,   18,  748,   87,
#          26,   36,   65,    9,   34,   41,   23,   27,   21,   35,   17,
#         468,   24,  317,   64,   86,  226,  205,  139,   83,   48,   72,
#         187,   99,   44,   76,   50,  234, 1115,  148,  536,  334,  111,
#         167,  292,  300,  168,  655,  238,   69,  369,   63,  308,  114,
#         230,   74,  172,  792,  532,  154,  122,  309,  251,  128,  561,
#         310,   53,  117,   77,   33,  170, 2547])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['From Other'])
plt.title("Distribution from other")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/1692400552.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Other'])

# %%
df["Saves"].unique()
# Out:
# array([  98,  194,   41,  172,   96,   74,   22,  135,  155,  122,   28,
#         119,  121,  100,  101,  111,  106,   82,   40,   49,   72,  167,
#          63,  144,   61,  139,   52,   84,   81,   79,  105,   90,   34,
#          45,   35,  252,  263,  137,   67,  288,  668,   42,  342,   48,
#         250,  219,  118,  143,   99,   89,  148,  171,  109,   38,  421,
#         116,  225,   51,  104,   33,  174,   46,  179,   70,  149,  207,
#         318,  393,  152,   83,   94,  188,  214,   73,  285,  469,  504,
#          55,  273,  182,  573,   36, 1095,  653])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Saves'])
plt.title("Distribution of saves")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/1341382535.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Saves'])

# %%
df["Comments"].unique()
# Out:
# array([ 9,  7, 11, 10,  5,  4,  6,  8, 17,  3, 19,  2, 13,  1,  0])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Comments'])
plt.title("Distribution of Comments")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/2194159238.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Comments'])

# %%
df["Shares"].unique()
# Out:
# array([ 5, 14,  1,  7,  4, 10,  9,  8,  3, 11, 18,  6, 20, 15,  0, 13,  2,
#        19, 41, 16, 12, 22, 27, 23, 17, 38, 75, 26])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Shares'])
plt.title("Distribution of shares")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/553858902.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Shares'])

# %%
df["Likes"].unique()
# Out:
# array([162, 224, 131, 213, 123, 144,  76, 124, 159, 191,  81, 151, 142,
#        294, 205, 121,  72,  91, 195, 129, 160, 175, 147, 114,  92, 214,
#        150, 122, 152, 196,  86,  85, 156,  82, 416, 180, 127, 167, 225,
#        137, 263, 328, 126, 236,  99, 212, 297, 186, 112, 149, 132, 115,
#        248, 178, 107, 269,  96, 134, 301, 187,  94, 138, 257,  95, 244,
#        190, 118, 170, 250, 275, 192, 203, 145, 168, 194, 171, 249, 308,
#        163, 210, 172, 373, 148, 549, 443])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Likes'])
plt.title("Distribution of Likes")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/4047443895.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Likes'])

# %%
df["Profile Visits"].unique()
# Out:
# array([ 35,  48,  62,  23,   8,   9,  26,  12,  36,  31,  29,  15,  20,
#        181,  17,  16,  21,  77,  10,  11, 144,  14,  19,  69,  57,  13,
#         24,  81,   4,   7,  18, 330,  32,  30,  39,  42,  22, 306,  45,
#         50,  37,  25, 347,  52,  41, 155,  38,  92,  75,  74, 467,  70,
#         46,  61, 237,  73,  34, 148, 611])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Profile Visits'])
plt.title("Distribution of Profile Visits")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/2143734267.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Profile Visits'])

# %%
df["Follows"].unique()
# Out:
# array([  2,  10,  12,   8,   0,   6,   4,  42,  30,  24, 100,  20,  26,
#         94,  18,  38,  74,  46,  16,  32,  14,  28,  34, 260,  96,  58,
#         80, 214, 228])

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Follows'])
plt.title("Distribution of Followers")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/3553945996.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Follows'])

# %%
#Feature emgimeering

#To find out the engagement rate
df['Engagement Rate']=(df['Saves']+df['Likes']+df['Comments']+df['Shares']+df['Profile Visits'])/df['Impressions']

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df["Engagement Rate"].unique()
# Out:
# array([0.07882653, 0.0902855 , 0.06117881, 0.09386042, 0.09372518,
#        0.06282183, 0.04959939, 0.08020333, 0.09709256, 0.08578372,
#        0.06627592, 0.09585652, 0.07067219, 0.09110697, 0.06251983,
#        0.05835806, 0.09170415, 0.08109814, 0.05220493, 0.06231824,
#        0.06928295, 0.04555751, 0.07169345, 0.07372215, 0.07022472,
#        0.08451739, 0.05598813, 0.06471439, 0.08231397, 0.05572139,
#        0.05505551, 0.07005708, 0.05143513, 0.06677412, 0.06254093,
#        0.05152596, 0.06145251, 0.07092732, 0.05842081, 0.07624936,
#        0.06375296, 0.07703081, 0.06808114, 0.06572165, 0.09086107,
#        0.12424383, 0.08319559, 0.07678698, 0.08235453, 0.10466012,
#        0.06804536, 0.08877173, 0.0550833 , 0.07820274, 0.07968501,
#        0.07221665, 0.0735235 , 0.06936246, 0.06089098, 0.09673444,
#        0.04120662, 0.07146238, 0.0702996 , 0.05500869, 0.10025096,
#        0.05370537, 0.07359874, 0.08241105, 0.07275603, 0.05442933,
# ...

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Engagement Rate'])
plt.title("Distribution of engagement rate")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/1636841683.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Engagement Rate'])

# %%
df[df['Engagement Rate']>0.10]
# Out:
#     Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 45         4298       3050            969           181          64    263
# 49        10386       4137           3551          2355         205    668
# 64         7571       3717            841          1716        1115    421
# 81         5273       2673           2003           433         114    318
# 82         5409       2643           2006          1068         230    393
# 91         6814       2816           2769           900         128    469
#
#     Comments  Shares  Likes  Profile Visits  Follows  \
# 45         6      19    225              21        4
# 49         8      41    328              42       38
# 64         7      12    269              50       46
# 81         9      22    250              25       10
# 82        10      27    275              38       14
# 91         8      22    249              24       16
#
#                                               Caption  \
# ...

# %%
#to find the co-relation between each column
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.show()
# Out:
# /var/folders/32/9sgd2m0n3dz_z3ksc_nm6kg00000gn/T/ipykernel_10829/1816603019.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="coolwarm")

# %%
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags', 'Engagement Rate'],
#       dtype='object')

# %%
#analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Impressions'],'g-',linewidth=0.9,label="Impressions")
plt.xlabel("Index")
plt.ylabel("Impressions")
plt.title("Trend of impressions")
plt.show()

# %%
df.tail(1)
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 101        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 101         5      26    443             611      228
#
#                                                Caption  \
# 101  175 Python Projects with Source Code solved an...
#
#                                               Hashtags  Engagement Rate
# 101  #python #pythonprogramming #pythonprojects #py...         0.047076

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df['From Home'],'g-',linewidth=0.9,label="From Home")
plt.plot(df.index,df['From Hashtags'],'b-',linewidth=0.9,label="From Hashtags")
plt.plot(df.index,df['From Explore'],'r-',linewidth=0.9,label="From Explore")
plt.xlabel("Index")
plt.ylabel("Features")
plt.legend()
plt.title("Trend of Home/hashtags/explore")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Comments'],'g-',linewidth=0.9,label="Comments")
plt.plot(df.index,df['Shares'],'b-',linewidth=0.9,label="Shares")
#plt.plot(df.index,df['Profile Visits'],'r-',linewidth=0.9,label="Visitors")
#plt.plot(df.index,df['Follows'],'y-',linewidth=0.9,label="followers")
plt.xlabel("Index")
plt.ylabel("Features")
plt.legend()
plt.title("Trend of share/comments/visitors/followers")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Profile Visits'],'r-',linewidth=0.9,label="Visitors")
plt.plot(df.index,df['Follows'],'y-',linewidth=0.9,label="followers")
plt.xlabel("Index")
plt.ylabel("Features")
plt.legend()
plt.title("Trend of share/comments/visitors/followers")
plt.show()

# %%
#analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Saves'],'g-',linewidth=0.9,label="Saves")
plt.xlabel("Index")
plt.ylabel("saves")
plt.title("Trend of saving the post")
plt.show()

# %%
#analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Likes'],'g-',linewidth=0.9,label="Likes")
plt.xlabel("Index")
plt.ylabel("Likes")
plt.title("Trend of liking the post")
plt.show()

# %%
#analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Profile Visits'],'g-',linewidth=0.9,label="visitors")
plt.xlabel("Index")
plt.ylabel("visitors")
plt.title("Trend of visitors for the post")
plt.show()

# %%
#analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Follows'],'g-',linewidth=0.9,label="followers")
plt.xlabel("Index")
plt.ylabel("followers")
plt.title("Trend of followers")
plt.show()

# %%
df.loc[40]
# Out:
# Impressions                                                    16062
# From Home                                                       3144
# From Hashtags                                                  11817
# From Explore                                                     564
# From Other                                                       468
# Saves                                                            252
# Comments                                                           6
# Shares                                                            20
# Likes                                                            416
# Profile Visits                                                   330
# Follows                                                           94
# Caption            280 Machine Learning Projects Solved & Explain...
# Hashtags           #data #datascience #dataanalysis #dataanalytic...
# Engagement Rate                                             0.063753
# ...

# %%
df.loc[90]
# Out:
# Impressions                                                    17396
# From Home                                                       1817
# From Hashtags                                                  10008
# From Explore                                                    5192
# From Other                                                       251
# Saves                                                            285
# Comments                                                           7
# Shares                                                             7
# Likes                                                            416
# Profile Visits                                                   467
# Follows                                                          260
# Caption            Here is a list of 100+ Machine Learning Algori...
# Hashtags           #machinelearning #machinelearningalgorithms #d...
# Engagement Rate                                             0.067947
# ...

# %%
df.loc[101]
# Out:
# Impressions                                                    36919
# From Home                                                      13473
# From Hashtags                                                   4176
# From Explore                                                   16444
# From Other                                                      2547
# Saves                                                            653
# Comments                                                           5
# Shares                                                            26
# Likes                                                            443
# Profile Visits                                                   611
# Follows                                                          228
# Caption            175 Python Projects with Source Code solved an...
# Hashtags           #python #pythonprogramming #pythonprojects #py...
# Engagement Rate                                             0.047076
# ...

# %%
#comparision for reach
sns.barplot(x=["From Home","From Hashtags","From Explore","From Other"],
             y=[df["From Home"].mean(),df["From Hashtags"].mean(),df["From Explore"].mean(),df["From Other"].mean()])
plt.show()

# %%
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags', 'Engagement Rate'],
#       dtype='object')

# %%
#comparsion for like,share,comment,save,follow
#comparision for reach
sns.barplot(x=["Likes","Shares","Comments","Saves","Follows"],
             y=[df["Likes"].mean(),df["Shares"].mean(),df["Comments"].mean(),df["Saves"].mean(),df["Follows"].mean()])
plt.show()

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Wordclouds to find highlighted hashtags
from wordcloud import WordCloud

plt.figure(figsize=(10,8))
hashtag = " ".join(df["Hashtags"].tolist())
wordcloud = WordCloud(width=800,height=500).generate(hashtag)
plt.imshow(wordcloud)
plt.title("WordCloud for Hashtags")
plt.show()

# %%
home_reach = (df['From Home'].sum()/df['Impressions'].sum())*100
home_reach
# Out:
# 42.17574759963303

# %%
hashtag_reach = (df['From Hashtags'].sum()/df['Impressions'].sum())*100
hashtag_reach
# Out:
# 33.246614315096394

# %%
explore_reach = (df['From Explore'].sum()/df['Impressions'].sum())*100
explore_reach
# Out:
# 19.90739667409657

# %%
save_reach = (df['Saves'].sum()/df['Impressions'].sum())*100
save_reach
# Out:
# 2.64429525755714

# %%
comments_reach = (df['Comments'].sum()/df['Impressions'].sum())*100
comments_reach
# Out:
# 0.10730857508122663

# %%
share_reach = (df['Shares'].sum()/df['Impressions'].sum())*100
share_reach
# Out:
# 0.157154070605068

# %%
like_reach = (df['Likes'].sum()/df['Impressions'].sum())*100
like_reach
# Out:
# 2.986755339760808

# %%
visitors_reach = (df['Profile Visits'].sum()/df['Impressions'].sum())*100
visitors_reach
# Out:
# 0.9233836645878389

# %%
followers_reach = (df['Follows'].sum()/df['Impressions'].sum())*100
followers_reach
# Out:
# 0.38551599195848085

# %% [markdown]
# In order to get better reach one should have:
# 1) Effective hashtags
# 2) focus more on comment and share from home
# 3) content should be useful and should be saved
# 4) context should be engaging so that the viewer will visit the profile and follow
# 5) sharing and saving increase followers ultimately increase the reach
# 6) home, followers, shares should have ood numbers
# 7) Fields or words like data science, AI, python, data analytics were more trending
